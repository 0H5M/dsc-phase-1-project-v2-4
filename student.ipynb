# %% [markdown]
# # NAME:GLORIA CHEPNGENO

# %% [markdown]
# # INSTRUCTOR:ANTONNY MUIKO

# %% [markdown]
# # steps followed
# - Importing python libraries
# - Loading Datasets
# - Preparing the Data.
#
# - Data Cleaning to deal with missing values and duplicate values
#
# - Data Visualizations
#
# - Exploratory Data Analysis (Univariate and Bivariate Analysis)
#
# - Conclusions and Recommendation.

# %% [markdown]
# # IMPORTING PYTHON LIBRARIES

# %%
# pd.read_csv('bom.movie_gross.csv')
# import libraries for manipulation of the data
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # DATA PREPARATIONS

# %%
## loading the datasets

# %%
pd.read_csv('zippedData/bom.movie_gross.csv')
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
pd.read_csv('zippedData/tmdb.movies.csv')
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# ...

# %%
pd.read_csv('zippedData/tn.movie_budgets.csv')
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# ...

# %%
pd.read_csv('zippedData/rt.movie_info.tsv' ,sep ='\t')
# Out:
#         id                                           synopsis rating  \
# 0        1  This gritty, fast-paced, and innovative police...      R
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 2        5  Illeana Douglas delivers a superb performance ...      R
# 3        6  Michael Douglas runs afoul of a treacherous su...      R
# 4        7                                                NaN     NR
# ...    ...                                                ...    ...
# 1555  1996  Forget terrorists or hijackers -- there's a ha...      R
# 1556  1997  The popular Saturday Night Live sketch was exp...     PG
# 1557  1998  Based on a novel by Richard Powell, when the l...      G
# 1558  1999  The Sandlot is a coming-of-age story about a g...     PG
# 1559  2000  Suspended from the force, Paris cop Hubert is ...      R
#
#                                                   genre            director  \
# ...

# %%
# selected datasets for analysis as from the tables below

# %%
df = pd.read_csv('zippedData/bom.movie_gross.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
df.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
df.tail()
# Out:
#                             title      studio  domestic_gross foreign_gross  \
# 3382                    The Quake       Magn.          6200.0           NaN
# 3383  Edward II (2018 re-release)          FM          4800.0           NaN
# 3384                     El Pacto        Sony          2500.0           NaN
# 3385                     The Swan  Synergetic          2400.0           NaN
# 3386            An Actor Prepares       Grav.          1700.0           NaN
#
#       year
# 3382  2018
# 3383  2018
# 3384  2018
# 3385  2018
# 3386  2018

# %%
df.shape
# Out:
# (3387, 5)

# %%
df.describe()
# Out:
#        domestic_gross         year
# count    3.359000e+03  3387.000000
# mean     2.874585e+07  2013.958075
# std      6.698250e+07     2.478141
# min      1.000000e+02  2010.000000
# 25%      1.200000e+05  2012.000000
# 50%      1.400000e+06  2014.000000
# 75%      2.790000e+07  2016.000000
# max      9.367000e+08  2018.000000

# %%
df.describe(include='all')
# Out:
#             title studio  domestic_gross foreign_gross         year
# count        3387   3382    3.359000e+03          2037  3387.000000
# unique       3386    257             NaN          1204          NaN
# top     Bluebeard    IFC             NaN       1200000          NaN
# freq            2    166             NaN            23          NaN
# mean          NaN    NaN    2.874585e+07           NaN  2013.958075
# std           NaN    NaN    6.698250e+07           NaN     2.478141
# min           NaN    NaN    1.000000e+02           NaN  2010.000000
# 25%           NaN    NaN    1.200000e+05           NaN  2012.000000
# 50%           NaN    NaN    1.400000e+06           NaN  2014.000000
# 75%           NaN    NaN    2.790000e+07           NaN  2016.000000
# max           NaN    NaN    9.367000e+08           NaN  2018.000000

# %%
df2= pd.read_csv('zippedData/tmdb.movies.csv')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26517 entries, 0 to 26516
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         26517 non-null  int64
#  1   genre_ids          26517 non-null  object
#  2   id                 26517 non-null  int64
#  3   original_language  26517 non-null  object
#  4   original_title     26517 non-null  object
#  5   popularity         26517 non-null  float64
#  6   release_date       26517 non-null  object
#  7   title              26517 non-null  object
#  8   vote_average       26517 non-null  float64
#  9   vote_count         26517 non-null  int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 2.0+ MB

# %%
df2.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# ...

# %%
df2.tail()
# Out:
#        Unnamed: 0        genre_ids      id original_language  \
# 26512       26512         [27, 18]  488143                en
# 26513       26513         [18, 53]  485975                en
# 26514       26514     [14, 28, 12]  381231                en
# 26515       26515  [10751, 12, 28]  366854                en
# 26516       26516         [53, 27]  309885                en
#
#               original_title  popularity release_date                  title  \
# 26512  Laboratory Conditions         0.6   2018-10-13  Laboratory Conditions
# 26513        _EXHIBIT_84xxx_         0.6   2018-05-01        _EXHIBIT_84xxx_
# 26514           The Last One         0.6   2018-10-01           The Last One
# 26515           Trailer Made         0.6   2018-06-22           Trailer Made
# 26516             The Church         0.6   2018-10-05             The Church
#
#        vote_average  vote_count
# 26512           0.0           1
# 26513           0.0           1
# 26514           0.0           1
# ...

# %%
df2.shape
# Out:
# (26517, 10)

# %%
df2.describe()
# Out:
#         Unnamed: 0             id    popularity  vote_average    vote_count
# count  26517.00000   26517.000000  26517.000000  26517.000000  26517.000000
# mean   13258.00000  295050.153260      3.130912      5.991281    194.224837
# std     7654.94288  153661.615648      4.355229      1.852946    960.961095
# min        0.00000      27.000000      0.600000      0.000000      1.000000
# 25%     6629.00000  157851.000000      0.600000      5.000000      2.000000
# 50%    13258.00000  309581.000000      1.374000      6.000000      5.000000
# 75%    19887.00000  419542.000000      3.694000      7.000000     28.000000
# max    26516.00000  608444.000000     80.773000     10.000000  22186.000000

# %%
df2.describe(include =('all'))
# Out:
#          Unnamed: 0 genre_ids             id original_language original_title  \
# count   26517.00000     26517   26517.000000             26517          26517
# unique          NaN      2477            NaN                76          24835
# top             NaN      [99]            NaN                en           Eden
# freq            NaN      3700            NaN             23291              7
# mean    13258.00000       NaN  295050.153260               NaN            NaN
# std      7654.94288       NaN  153661.615648               NaN            NaN
# min         0.00000       NaN      27.000000               NaN            NaN
# 25%      6629.00000       NaN  157851.000000               NaN            NaN
# 50%     13258.00000       NaN  309581.000000               NaN            NaN
# 75%     19887.00000       NaN  419542.000000               NaN            NaN
# max     26516.00000       NaN  608444.000000               NaN            NaN
#
# ...

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'genre_ids', 'id', 'original_language', 'original_title',
#        'popularity', 'release_date', 'title', 'vote_average', 'vote_count'],
#       dtype='object')

# %% [markdown]
# # DATA CLEANING
# # EXPLORATORY DATA ANALYSIS(EDA)

# %%
# MERGE THE TWO DATASETS IN ONE VARIABLE

# %%
movies_ratings = pd.merge(df, df2)
movies_ratings.head()
# Out:
#                         title studio  domestic_gross foreign_gross  year  \
# 0                 Toy Story 3     BV     415000000.0     652000000  2010
# 1                   Inception     WB     292600000.0     535700000  2010
# 2         Shrek Forever After   P/DW     238700000.0     513900000  2010
# 3  The Twilight Saga: Eclipse   Sum.     300500000.0     398000000  2010
# 4                  Iron Man 2   Par.     312400000.0     311500000  2010
#
#    Unnamed: 0                genre_ids     id original_language  \
# 0           7          [16, 10751, 35]  10193                en
# 1           4            [28, 878, 12]  27205                en
# 2          38  [35, 12, 14, 16, 10751]  10192                en
# 3          15      [12, 14, 18, 10749]  24021                en
# 4           2            [12, 28, 878]  10138                en
#
#                original_title  popularity release_date  vote_average  \
# ...

# %%
# check for null and duplicate values

# %%
movies_ratings.isnull().sum()
# Out:
# title                  0
# studio                 1
# domestic_gross        21
# foreign_gross        980
# year                   0
# Unnamed: 0             0
# genre_ids              0
# id                     0
# original_language      0
# original_title         0
# popularity             0
# release_date           0
# vote_average           0
# vote_count             0
# dtype: int64

# %%
movies_ratings.dropna(how='any', axis = 1 , inplace = True)

# %%
movies_ratings.isnull().sum()
# Out:
# title                0
# year                 0
# Unnamed: 0           0
# genre_ids            0
# id                   0
# original_language    0
# original_title       0
# popularity           0
# release_date         0
# vote_average         0
# vote_count           0
# dtype: int64

# %%
movies_ratings.duplicated().sum()
# Out:
# 0

# %%
movies_ratings.groupby('title')['vote_average'].mean().head()
# Out:
# title
# '71                    6.8
# 10 Cloverfield Lane    6.9
# 10 Years               5.8
# 11-11-11               4.3
# 12 Strong              5.6
# Name: vote_average, dtype: float64

# %%
movies_ratings.groupby('title')['vote_count'].mean().head()
# Out:
# title
# '71                     627.0
# 10 Cloverfield Lane    4629.0
# 10 Years                299.0
# 11-11-11                116.0
# 12 Strong              1312.0
# Name: vote_count, dtype: float64

# %%
movies_ratings.groupby('title')['vote_average'].mean().sort_values(ascending=False).head()
# Out:
# title
# Fatima                            10.000000
# Buena Vista Social Club: Adios     9.500000
# Nerve                              9.033333
# The Green Wave                     8.700000
# Your Name.                         8.600000
# Name: vote_average, dtype: float64

# %%
movies_ratings.groupby('title')['vote_count'].mean().sort_values(ascending=False).head()
# Out:
# title
# Inception                  22186.0
# Deadpool                   20175.0
# Interstellar               18597.0
# Guardians of the Galaxy    17958.0
# Django Unchained           15725.0
# Name: vote_count, dtype: float64

# %%
movies_ratings.groupby('title')['vote_count'].count().sort_values(ascending=False).head()
# Out:
# title
# Eden             7
# Legend           5
# Truth or Dare    5
# Split            4
# Extraction       4
# Name: vote_count, dtype: int64

# %%
rating_mean = pd.DataFrame(movies_ratings.groupby('title')['vote_average'].mean())

# %%
rating_mean.head()
# Out:
#                      vote_average
# title
# '71                           6.8
# 10 Cloverfield Lane           6.9
# 10 Years                      5.8
# 11-11-11                      4.3
# 12 Strong                     5.6

# %%
movies_ratings.groupby('title')['vote_average'].count().sort_values(ascending=False).head()
# Out:
# title
# Eden             7
# Legend           5
# Truth or Dare    5
# Split            4
# Extraction       4
# Name: vote_average, dtype: int64

# %% [markdown]
# # DATA VISUALIZATION

# %%
# visualize the data sets using bar graphs

# %%
list(movies_ratings.columns)
# Out:
# ['title',
#  'year',
#  'Unnamed: 0',
#  'genre_ids',
#  'id',
#  'original_language',
#  'original_title',
#  'popularity',
#  'release_date',
#  'vote_average',
#  'vote_count']

# %%
movies_ratings.count()
# Out:
# title                2703
# year                 2703
# Unnamed: 0           2703
# genre_ids            2703
# id                   2703
# original_language    2703
# original_title       2703
# popularity           2703
# release_date         2703
# vote_average         2703
# vote_count           2703
# dtype: int64

# %%
plt.figure(figsize=(10,6))
plt.rcParams['patch.force_edgecolor'] = True
rating_mean['vote_average'].hist(bins=40)
plt.xticks(rotation = 50)
plt.xlabel('vote_average')
plt.ylabel('popularity')
# Out:
# Text(0, 0.5, 'popularity')

# %%
movies_ratings.boxplot()
# plt.xticks(rotations=90)
plt.figure(figsize=(20,15))

# %%
plt.figure(figsize=(20,12))
sns.boxplot(x=movies_ratings['popularity'],color='Red')
# Out:
# <AxesSubplot:xlabel='popularity'>

# %%
# the above dataset has some outliers which need to be removed for easy analysis and understanding

# %%
plt.figure(figsize=(10,6))
plt.rcParams['patch.force_edgecolor'] = True
movies_ratings['vote_count'].hist(bins=40)
plt.xlabel('vote_average')
plt.ylabel('popularity')
# Out:
# Text(0, 0.5, 'popularity')

# %%
plt.figure(figsize=(10,6))
plt.rcParams['patch.force_edgecolor'] = True
sns.jointplot(x='vote_average',y='vote_count',data=movies_ratings,alpha=0.7)

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(movies_ratings['vote_count'],movies_ratings['vote_average'])
ax.set_xlabel('vote_count')
ax.set_ylabel('vote_average')
plt.show();

# %%
fig = plt.figure(figsize= (13,8))
titles = df['title'].head(10)
domestic_margin = df['domestic_gross'].head(10)
# creating the bar graph
plt.bar(titles, domestic_margin, width= 0.5)
plt.xlabel('title')
plt.ylabel('domestic_gross')
# plt.title('The top 10 films')
plt.xticks(rotation = 90)
plt.show()

# %%
movies_ratings.head()
# Out:
#                         title  year  Unnamed: 0                genre_ids  \
# 0                 Toy Story 3  2010           7          [16, 10751, 35]
# 1                   Inception  2010           4            [28, 878, 12]
# 2         Shrek Forever After  2010          38  [35, 12, 14, 16, 10751]
# 3  The Twilight Saga: Eclipse  2010          15      [12, 14, 18, 10749]
# 4                  Iron Man 2  2010           2            [12, 28, 878]
#
#       id original_language              original_title  popularity  \
# 0  10193                en                 Toy Story 3      24.445
# 1  27205                en                   Inception      27.920
# 2  10192                en         Shrek Forever After      15.041
# 3  24021                en  The Twilight Saga: Eclipse      20.340
# 4  10138                en                  Iron Man 2      28.515
#
#   release_date  vote_average  vote_count
# 0   2010-06-17           7.7        8340
# ...

# %%
movies_ratings.drop('release_date' , axis=1 )
# Out:
#                            title  year  Unnamed: 0                genre_ids  \
# 0                    Toy Story 3  2010           7          [16, 10751, 35]
# 1                      Inception  2010           4            [28, 878, 12]
# 2            Shrek Forever After  2010          38  [35, 12, 14, 16, 10751]
# 3     The Twilight Saga: Eclipse  2010          15      [12, 14, 18, 10749]
# 4                     Iron Man 2  2010           2            [12, 28, 878]
# ...                          ...   ...         ...                      ...
# 2698                  The Escape  2018       16803                 [53, 28]
# 2699                  The Escape  2018       19053                 [53, 28]
# 2700                    Souvenir  2018       18483                 [35, 18]
# 2701                   The Quake  2018       24107                     [12]
# 2702           An Actor Prepares  2018       24419                 [35, 18]
#
# ...

# %%
fig = plt.figure(figsize= (13,8))
titles = df['title'].head(10)
foreign_margin = df['foreign_gross'].head(10)
# creating the bar graph
plt.bar(titles, domestic_margin, width= 0.5)
plt.xlabel('title')
plt.ylabel('foreign_gross')
# plt.title('The top 10 films')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # RELATIONSHIPS BETWEEN MOVIE RATINGS

# %% [markdown]
# # RECCOMENDATIONS BASED ON CORRELATION

# %% [markdown]
# # BIVARIATE ANALYSIS
# # CATEGORICAL

# %%
# ratings based on the averages and vote count
# consider the relatinships between two variables can be two columns or more

# %%
movies_rating_user = movies_ratings.pivot_table(index='id', columns='title', values ='vote_average')

# %%
movies_rating_user.head()
# Out:
# title  '71  10 Cloverfield Lane  10 Years  11-11-11  12 Strong  \
# id
# 1771   NaN                  NaN       NaN       NaN        NaN
# 1865   NaN                  NaN       NaN       NaN        NaN
# 1930   NaN                  NaN       NaN       NaN        NaN
# 4258   NaN                  NaN       NaN       NaN        NaN
# 5178   NaN                  NaN       NaN       NaN        NaN
#
# title  12 Years a Slave  127 Hours  13 Assassins  \
# id
# 1771                NaN        NaN           NaN
# 1865                NaN        NaN           NaN
# 1930                NaN        NaN           NaN
# 4258                NaN        NaN           NaN
# 5178                NaN        NaN           NaN
#
# title  13 Hours: The Secret Soldiers of Benghazi  13 Minutes  ...  Youth  \
# id                                                            ...
# 1771                                         NaN         NaN  ...    NaN
# ...

# %%
fatima_ratings = movies_rating_user['Eden']
fatima_ratings.head()
# Out:
# id
# 1771   NaN
# 1865   NaN
# 1930   NaN
# 4258   NaN
# 5178   NaN
# Name: Eden, dtype: float64

# %%
movies_similar_fatima = movies_rating_user.corrwith(fatima_ratings)
fatima_corr =pd.DataFrame(movies_similar_fatima, columns=['Correlation'])
fatima_corr.dropna(inplace=True)
fatima_corr.head(10)
# Out:
#        Correlation
# title
# Eden           1.0

# %%
fatima_corr = fatima_corr.join(rating_mean['vote_average'])
fatima_corr.head()
# Out:
#        Correlation  vote_average
# title
# Eden           1.0      4.942857

# %%
 print(f'release_date: {movies_ratings.release_date.count()}')
# Out:
# release_date: 2703

# %%
movies_ratings.columns
# Out:
# Index(['title', 'year', 'Unnamed: 0', 'genre_ids', 'id', 'original_language',
#        'original_title', 'popularity', 'release_date', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
sns.heatmap(movies_ratings.corr())
plt.show();

# %%
# the heatmap above gives more information found  between variables assigned

# %%
sns.pairplot(movies_ratings)
plt.show();

# %%
# the above pairplot is meant for reference to enhance better understanding

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %%
# consider a single column to analyse the data

# %%
pd.plotting.scatter_matrix(movies_ratings);
plt.xticks(rotation = 50)
# Out:
# (array([-20000.,      0.,  20000.,  40000.]),
#  [Text(0, 0, ''), Text(0, 0, ''), Text(0, 0, ''), Text(0, 0, '')])

# %%
# the scatter plot can also be used for reference just like the pairplot

# %%
movies_ratings.rename(columns = {'popularity':'popularity'},inplace=True)

# %%
movies_ratings['popularity']= movies_ratings.popularity.astype('int64')

# %%
movies_ratings.popularity.dtype
# Out:
# dtype('int64')

# %%
movies_ratings['vote_average']= movies_ratings.vote_average.astype('int64')

# %%
list(df.columns)
# Out:
# ['title', 'studio', 'domestic_gross', 'foreign_gross', 'year']

# %%
# analysis for the year column
# visualize them on a bargrapgh

# %%
sns.countplot(df['year'])
plt.title('Movies per year' , fontsize = 20)
plt.xlabel('year', fontsize = 15)
plt.ylabel('Number of movies' , fontsize =15)
plt.show()
# Out:
# C:\Users\Gloria\anaconda3\envs\learn-env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fig = plt.figure(figsize= (13,8))
titles = df['title'].head(10)
domestic_margin = df['domestic_gross'].head(10)
# creating the bar graph
plt.bar(titles, domestic_margin, width= 0.5)
plt.xlabel('title')
plt.ylabel('domestic_gross')
# plt.title('The top 10 films')
plt.xticks(rotation = 90)
plt.show()

# %%
sns.countplot(movies_ratings['year'])
plt.title('Movies per year' , fontsize = 20)
plt.xlabel('year', fontsize = 15)
plt.ylabel('Number of movies' , fontsize =15)
plt.show()
# Out:
# C:\Users\Gloria\anaconda3\envs\learn-env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fig = plt.figure(figsize= (13,8))
titles = df['title'].head(10)
foreign_margin = df['foreign_gross'].head(10)
# creating the bar graph
plt.bar(titles, domestic_margin, width= 0.5)
plt.xlabel('title')
plt.ylabel('foreign_gross')
# plt.title('The top 10 films')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # CONCLUSCION
# Based on the above univariate analysis, it visible that movies differ based on there ratings and the year that they were released,,movies that were releasedsome years back around 2010 have significant lower rating thean movies released on 2015 and 2016 ,,the reason might be because the latest movies contains more content as technology increases per year.So basically latest movies were produced in a high number on the most recent years..... According the whole analysis of data ,,i have been able to yield some information on the relationship between some variables for instance the movie'Eden'.i thereby conclude that latest movies are more relevant compared to old movies as they are outdated however could have educative lessons at the same time…The foreign gross and domestic gross for ‘Toy Story 3’ is high ,,because of its popularity and has the most relevant information unlike for ‘How to train your Dragon’

# %% [markdown]
# # RECCOMENDATIONS
# I reccomend you to create films from the movies currently being produced by famous producers with popular actors ,this is because they have the highest rated movies ,,reason being they are creative and make relevant movies meant fro different ages with appropriate content..Also they have the highest vote counts an this means that such movies are the top picks even in movie websites and known for the production of best movies and probably has the highest gross...I would recommend the latest movies that are closely similar to TOY STORY 3 SERIES as from the analysis we have done ..
